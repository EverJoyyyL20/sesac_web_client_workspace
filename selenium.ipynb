# %% [markdown]
# # Selenium

# %% [markdown]
# ## install Selenium

# %%
pip install selenium
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ------------------- -------------------- 4.7/9.7 MB 23.3 MB/s eta 0:00:01
#    -------------------------- ------------- 6.3/9.7 MB 17.3 MB/s eta 0:00:01
#    -------------------------------------- - 9.2/9.7 MB 16.0 MB/s eta 0:00:01
#    ---------------------------------------- 9.7/9.7 MB 14.0 MB/s eta 0:00:00
# ...
#
#    ---------------------------------------- 0/7 [wsproto]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----- ---------------------------------- 1/7 [urllib3]
#    ----------- ---------------------------- 2/7 [typing_extensions]
# ...

# %%
pip install webdriver_manager
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver

from selenium.webdriver.chrome.service import Service as ChromeService
from webdriver_manager.chrome import ChromeDriverManager

# %% [markdown]
# ### 브라우저 열기

# %%
driver=webdriver.Chrome(service=ChromeService(ChromeDriverManager().install()))

# %%
driver.get("https://www.naver.com/")
# driver의 get함수를 이용하여 크롬 브라우저에서 페이지를 이동가능
# 아래의 코드는 naver웹 페이지로 이동 가능
# url은 http를 꼭 포함

# %%
driver.set_window_size(1024,768)

# 윈도우 사이즈 조절
# driver의 set_window_size 함수를 이용하여 윈도우 사이즈를 조절가능
# 함수내의 첫번째 파라미터는 가로사이즈를 나타내며 두번째 파라미터는 세로 사이즈를 나타냅니다.

# %%
driver.execute_script("window.scrollTo(200,300);")

#javascirpt의 window.scrollTo 함수의 첫번째 파라미터는 가로축 위치를 나타내며 아 래 코드와 같이 200으로 설정을 하면 왼쪽에서 200
#두번째 파라미 터는 세로축의 위치를 나타내며 아래의 코드와 같이 300으로 지정을 하면 위에서 아래로 300픽셀 만큼 스크롤이 내려감
#을 의미합니다.

# %%
try:
    alert=driver.switch_to.alert
    print(alert.text)
except:
    print("alert 없음")

# 크롤링이나 자동화를 하는 중간에 alert메시지가 나오는 경우가 있습니다.4
# 이럴때 크롤링이나 자동화를 계속 하게 하기위해 alert메시지를 다룰줄알아야함
# Out:
# alert 없음

# %%
driver.execute_script("alert('selenium test');")

# %%
try:
    alert=driver.switch_to.alert
    print(alert.text)
except:
    print('alert 없음')
# Out:
# selenium test

# %%
alert.accept()
#alert확인 버튼 누르기

# %% [markdown]
# ## 버튼 클릭하기

# %%
from selenium.webdriver.common.by import By
driver.find_element(By.CSS_SELECTOR,".MyView-module__link_login___HpHMW").click()

## 네이버 로그인 버튼 클래스 지정 로그인버튼 나오게 함.
