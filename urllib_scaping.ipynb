# %% [markdown]
# # urllib 사용법 및 기본 스크랩핑

# %%
import urllib.request as req
# 인터넷에서 파일을 가져오는 기능을 사용하겠다.

img_url="https://sesac.seoul.kr/static/common/images/www/common/img_ssac_intro.png"

html_url="http://google.com"

# %%
save_path1="C:/Myexam/test1.jpg"
save_path2="C:/Myexam/index.html"

# %%
try:
    file1,header1=req.urlretrieve(img_url,save_path1)
    file2,header2=req.urlretrieve(html_url,save_path2)
except Exception as e:
    print("Download failed")
    print(e)
else:
    print(header1)
    print(header2)
# Out:
# Date: Mon, 08 Dec 2025 05:50:24 GMT
# Content-Type: image/png
# Content-Length: 31431
# Connection: close
# Accept-Ranges: bytes
# ETag: W/"31431-1677198054000"
# Last-Modified: Fri, 24 Feb 2023 00:20:54 GMT
#
#
# Date: Mon, 08 Dec 2025 05:30:57 GMT
# Expires: -1
# Cache-Control: private, max-age=0
# Content-Type: text/html; charset=ISO-8859-1
# Content-Security-Policy-Report-Only: object-src 'none';base-uri 'self';script-src 'nonce-7In0ontXbTmhBlKU5VA_Ww' 'strict-dynamic' 'report-sample' 'unsafe-eval' 'unsafe-inline' https: http:;report-uri https://csp.withgoogle.com/csp/gws/other-hp
# P3P: CP="This is not a P3P policy! See g.co/p3phelp for more info."
# Server: gws
# X-XSS-Protection: 0
# X-Frame-Options: SAMEORIGIN
# Set-Cookie: AEC=AaJma5sPS-d4fgnNnyu6A4-eKpn1Ej_VxDUlRGJY4GuTy0rQIaeb6Mo0KA; expires=Sat, 06-Jun-2026 05:30:57 GMT; path=/; domain=.google.com; Secure; HttpOnly; SameSite=lax
# Set-Cookie: NID=527=rHrzl9HqxR_OkBpBXlcruoiAW_1Xl0BFUsslmPSYJTSSZJRN24on6lpJR7mJtfhBzqdY9blEW936n_BCOMVGZklrqlHtL5xfTaKNZMvW1pcQ2zv6tv130U1pjVuExl1vE5dtNKLw-aPosXLk3qpsUzPZP1pxYaEJ4xnl3ROBZfk4lVJjIYRBWwTE5pGvCeH3TZtBsdI5A5zPGGwMg8mzJDRW9khTGCs; expires=Tue, 09-Jun-2026 05:30:57 GMT; path=/; domain=.google.com; HttpOnly
# Accept-Ranges: none
# Vary: Accept-Encoding
# Connection: close
# Transfer-Encoding: chunked

# %%
print("Filename1 {}".format(file1))
print("Filename2 {}".format(file2))
# Out:
# Filename1 C:/Myexam/test1.jpg
# Filename2 C:/Myexam/index.html

# %%
print("Download Succed.")
# Out:
# Download Succed.
